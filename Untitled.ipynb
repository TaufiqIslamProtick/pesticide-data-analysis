# %%
import pandas as pd
df = pd.read_csv("./Input/pesticide_use.csv", encoding = "cp1252")
# Out:
# /tmp/ipykernel_32876/1982642172.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./Input/pesticide_use.csv", encoding = "cp1252")

# %%
df = df[df["Unit"] == "g/Int$"]

# %%
continents_to_filter = ['Africa', 'Asia', 'Europe', 'Northern America', 'Central America', 'South America', 'Oceania']
filtered_df = df[df['Area'].isin(continents_to_filter)]

# %%
grouped_stats = filtered_df.groupby('Area')['Value'].agg(['mean', 'std'])
grouped_stats["Area"] = grouped_stats.index
grouped_stats
# Out:
#                       mean       std              Area
# Area
# Africa            0.428438  0.063860            Africa
# Asia              0.594688  0.065795              Asia
# Central America   1.210000  0.181659   Central America
# Europe            0.918750  0.049693            Europe
# Northern America  1.332812  0.118872  Northern America
# Oceania           0.830000  0.186496           Oceania
# South America     1.707812  0.613976     South America

# %%
import matplotlib.pyplot as plt
df = grouped_stats

# Plotting grouped bar chart
fig, ax = plt.subplots()

# Set the width of each bar
bar_width = 0.35

# Set the positions of the bars on the x-axis
x = range(len(df))

# Plotting bars for mean
bars1 = ax.bar(x, df['mean'], width=bar_width, label='Mean', color='b')

# Plotting bars for standard deviation
bars2 = ax.bar([p + bar_width for p in x], df['std'], width=bar_width, label='Std', color='r')

# Labeling the x-axis ticks with area names
ax.set_xticks([p + bar_width / 2 for p in x])
ax.set_xticklabels(df['Area'], rotation=90)

# Adding labels, title, and legend
ax.set_xlabel('Area')
ax.set_ylabel('Value')
ax.set_title('Mean and Standard Deviation by Area')
ax.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
groupedseries = filtered_df.groupby('Area')
listofdfs = [group for _, group in groupedseries]
colors = ['violet','indigo','blue','green','brown','orange','red']
plt.figure(figsize=[12,6])
for i in range(len(listofdfs)):
    temp = listofdfs[i]
    label = temp['Area'].unique()[0]
    plt.plot(
        temp['Year'],
        temp['Value'],
        marker = None,
        linestyle = '-',
        color = colors[i],
        label =label
    )
plt.xlabel('Year')
plt.ylabel('g/Int$')
plt.title('Gram per International Dollar Value vs. Year across the continents.')
plt.legend()
plt.show()

# %%
traindfs = []
testdfs = []
for i in range(len(listofdfs)):
    traindfs.append(listofdfs[i].head(len(listofdfs[i])-1))
    testdfs.append(listofdfs[i].tail(1))

# %%
traindfs[1]
# Out:
#         Area Code Area Code (M49)  Area  Item Code                Item  \
# 103301       5300            '142  Asia       1357  Pesticides (total)
# 103302       5300            '142  Asia       1357  Pesticides (total)
# 103303       5300            '142  Asia       1357  Pesticides (total)
# 103304       5300            '142  Asia       1357  Pesticides (total)
# 103305       5300            '142  Asia       1357  Pesticides (total)
# 103306       5300            '142  Asia       1357  Pesticides (total)
# 103307       5300            '142  Asia       1357  Pesticides (total)
# 103308       5300            '142  Asia       1357  Pesticides (total)
# 103309       5300            '142  Asia       1357  Pesticides (total)
# 103310       5300            '142  Asia       1357  Pesticides (total)
# 103311       5300            '142  Asia       1357  Pesticides (total)
# 103312       5300            '142  Asia       1357  Pesticides (total)
# 103313       5300            '142  Asia       1357  Pesticides (total)
# 103314       5300            '142  Asia       1357  Pesticides (total)
# 103315       5300            '142  Asia       1357  Pesticides (total)
# 103316       5300            '142  Asia       1357  Pesticides (total)
# 103317       5300            '142  Asia       1357  Pesticides (total)
# 103318       5300            '142  Asia       1357  Pesticides (total)
# 103319       5300            '142  Asia       1357  Pesticides (total)
# 103320       5300            '142  Asia       1357  Pesticides (total)
# 103321       5300            '142  Asia       1357  Pesticides (total)
# 103322       5300            '142  Asia       1357  Pesticides (total)
# 103323       5300            '142  Asia       1357  Pesticides (total)
# 103324       5300            '142  Asia       1357  Pesticides (total)
# 103325       5300            '142  Asia       1357  Pesticides (total)
# 103326       5300            '142  Asia       1357  Pesticides (total)
# 103327       5300            '142  Asia       1357  Pesticides (total)
# 103328       5300            '142  Asia       1357  Pesticides (total)
# 103329       5300            '142  Asia       1357  Pesticides (total)
# 103330       5300            '142  Asia       1357  Pesticides (total)
# 103331       5300            '142  Asia       1357  Pesticides (total)
#
#         Element Code                                   Element  Year Code  \
# 103301          5173  Use per value of agricultural production       1990
# 103302          5173  Use per value of agricultural production       1991
# 103303          5173  Use per value of agricultural production       1992
# 103304          5173  Use per value of agricultural production       1993
# 103305          5173  Use per value of agricultural production       1994
# 103306          5173  Use per value of agricultural production       1995
# 103307          5173  Use per value of agricultural production       1996
# 103308          5173  Use per value of agricultural production       1997
# 103309          5173  Use per value of agricultural production       1998
# 103310          5173  Use per value of agricultural production       1999
# 103311          5173  Use per value of agricultural production       2000
# 103312          5173  Use per value of agricultural production       2001
# 103313          5173  Use per value of agricultural production       2002
# 103314          5173  Use per value of agricultural production       2003
# 103315          5173  Use per value of agricultural production       2004
# 103316          5173  Use per value of agricultural production       2005
# 103317          5173  Use per value of agricultural production       2006
# 103318          5173  Use per value of agricultural production       2007
# 103319          5173  Use per value of agricultural production       2008
# 103320          5173  Use per value of agricultural production       2009
# 103321          5173  Use per value of agricultural production       2010
# 103322          5173  Use per value of agricultural production       2011
# 103323          5173  Use per value of agricultural production       2012
# 103324          5173  Use per value of agricultural production       2013
# 103325          5173  Use per value of agricultural production       2014
# 103326          5173  Use per value of agricultural production       2015
# 103327          5173  Use per value of agricultural production       2016
# 103328          5173  Use per value of agricultural production       2017
# 103329          5173  Use per value of agricultural production       2018
# 103330          5173  Use per value of agricultural production       2019
# 103331          5173  Use per value of agricultural production       2020
#
#         Year    Unit  Value Flag Note
# 103301  1990  g/Int$   0.72    E  NaN
# 103302  1991  g/Int$   0.69    E  NaN
# 103303  1992  g/Int$   0.68    E  NaN
# 103304  1993  g/Int$   0.67    E  NaN
# 103305  1994  g/Int$   0.67    E  NaN
# 103306  1995  g/Int$   0.67    E  NaN
# 103307  1996  g/Int$   0.66    E  NaN
# 103308  1997  g/Int$   0.65    E  NaN
# 103309  1998  g/Int$   0.61    E  NaN
# 103310  1999  g/Int$   0.61    E  NaN
# 103311  2000  g/Int$   0.59    E  NaN
# 103312  2001  g/Int$   0.59    E  NaN
# 103313  2002  g/Int$   0.59    E  NaN
# 103314  2003  g/Int$   0.60    E  NaN
# 103315  2004  g/Int$   0.61    E  NaN
# 103316  2005  g/Int$   0.58    E  NaN
# 103317  2006  g/Int$   0.57    E  NaN
# 103318  2007  g/Int$   0.61    E  NaN
# 103319  2008  g/Int$   0.60    E  NaN
# 103320  2009  g/Int$   0.61    E  NaN
# 103321  2010  g/Int$   0.64    E  NaN
# 103322  2011  g/Int$   0.57    E  NaN
# 103323  2012  g/Int$   0.58    E  NaN
# 103324  2013  g/Int$   0.56    E  NaN
# 103325  2014  g/Int$   0.53    E  NaN
# 103326  2015  g/Int$   0.56    E  NaN
# 103327  2016  g/Int$   0.59    E  NaN
# 103328  2017  g/Int$   0.53    E  NaN
# 103329  2018  g/Int$   0.50    E  NaN
# 103330  2019  g/Int$   0.49    E  NaN
# 103331  2020  g/Int$   0.44    E  NaN
